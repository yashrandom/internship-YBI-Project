# %%
#importing pandas and msno
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/Download diabetes_dataset_with_missing_values.csv")

# %%
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6.0     94.0           64.0           49.0    124.0   NaN
# 1             3.0     82.0          112.0           13.0    206.0  40.8
# 2            12.0     94.0          105.0           56.0    107.0  25.5
# 3             NaN    137.0          118.0           40.0     70.0  42.0
# 4            10.0    136.0           89.0           37.0     74.0   NaN
# ...           ...      ...            ...            ...      ...   ...
# 1195          6.0    107.0           84.0           49.0    146.0  25.1
# 1196          5.0      NaN           50.0           17.0    274.0  35.1
# 1197          9.0    181.0          116.0           49.0    139.0  49.9
# 1198         13.0    150.0           92.0           53.0     96.0   NaN
# 1199         11.0    173.0          111.0           32.0    185.0  45.1
#
#       DiabetesPedigreeFunction   Age  Outcome
# 0                         1.62  29.0        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               1056 non-null   float64
#  1   Glucose                   1056 non-null   float64
#  2   BloodPressure             1056 non-null   float64
#  3   SkinThickness             1056 non-null   float64
#  4   Insulin                   1056 non-null   float64
#  5   BMI                       1056 non-null   float64
#  6   DiabetesPedigreeFunction  1056 non-null   float64
#  7   Age                       1056 non-null   float64
#  8   Outcome                   1200 non-null   int64
# dtypes: float64(8), int64(1)
# memory usage: 84.5 KB

# %%
df.describe(include='all')
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  1200.000000  1200.000000    1200.000000    1200.000000  1200.000000
# mean      6.985000   132.611667      80.179167      34.963333   146.701667
# std       4.116904    35.904389      21.538655      13.605927    70.321964
# min       0.000000    70.000000      40.000000      10.000000    15.000000
# 25%       4.000000   104.000000      63.000000      24.000000    92.750000
# 50%       7.000000   131.000000      80.000000      35.000000   148.000000
# 75%      11.000000   161.000000      97.000000      46.000000   203.000000
# max      14.000000   199.000000     121.000000      59.000000   275.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  1200.000000               1200.000000  1200.000000  1200.000000
# mean     33.748750                  1.301333    50.309167     0.488333
# std       8.614567                  0.645217    16.103458     0.500072
# ...

# %%
df.isna().sum()
# Out:
# Pregnancies                 144
# Glucose                     144
# BloodPressure               144
# SkinThickness               144
# Insulin                     144
# BMI                         144
# DiabetesPedigreeFunction    144
# Age                         144
# Outcome                       0
# dtype: int64

# %%
#Fill missing entries for Pregnancies
df['Pregnancies'] = df['Pregnancies'].fillna(df['Pregnancies'].median())

# %%
#Fill missing entries for Glucose
df['Glucose'] = df['Glucose'].fillna(df['Glucose'].median())

# %%
#Fill missing entries for BloodPressure
df['BloodPressure'] = df['BloodPressure'].fillna(df['BloodPressure'].median())

# %%
#Fill missing entries for SkinThickness
df['SkinThickness'] = df['SkinThickness'].fillna(df['SkinThickness'].median())

# %%
#Fill missing entries for Insulin
df['Insulin'] = df['Insulin'].fillna(df['Insulin'].median())

# %%
#Fill missing entries for BMI
df['BMI'] = df['BMI'].fillna(df['BMI'].median())

# %%
#Fill missing entries for DiabetesPedigreeFunction
df['DiabetesPedigreeFunction'] = df['DiabetesPedigreeFunction'].fillna(df['DiabetesPedigreeFunction'].median())

# %%
#Fill missing values for Age
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               1200 non-null   float64
#  1   Glucose                   1200 non-null   float64
#  2   BloodPressure             1200 non-null   float64
#  3   SkinThickness             1200 non-null   float64
#  4   Insulin                   1200 non-null   float64
#  5   BMI                       1200 non-null   float64
#  6   DiabetesPedigreeFunction  1200 non-null   float64
#  7   Age                       1200 non-null   float64
#  8   Outcome                   1200 non-null   int64
# dtypes: float64(8), int64(1)
# memory usage: 84.5 KB

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# Define y and X
X = df.drop(['Outcome'],axis=1)
y = df['Outcome']

# %%
# Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=2529)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((840, 8), (360, 8), (840,), (360,))

# %%
#Select Model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1200)

# %%
#Train Model
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1200)

# %%
model.intercept_
# Out:
# array([0.50750241])

# %%
model.coef_
# Out:
# array([[ 0.00651921, -0.00173278,  0.00178925,  0.0023284 , -0.00113163,
#         -0.01121951,  0.17220341, -0.00517607]])

# %%
#Prediction
y_pred = model.predict(X_test)

# %%
#Evaluate
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
confusion_matrix(y_test, y_pred)
# Out:
# array([[90, 96],
#        [93, 81]])

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.475

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.48      0.49       186
#            1       0.46      0.47      0.46       174
#
#     accuracy                           0.47       360
#    macro avg       0.47      0.47      0.47       360
# weighted avg       0.48      0.47      0.48       360
